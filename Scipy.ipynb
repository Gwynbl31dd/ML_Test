# %% [markdown]
# <a href="https://colab.research.google.com/github/Gwynbl31dd/ML_Test/blob/master/Scipy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PDF and CDF

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from scipy.stats import norm

# %%
x = np.linspace(-6,6,1000)

# %%
fx = norm.pdf(x, loc=0,scale=1)

# %%
plt.plot(x,fx);

# %%
Fx = norm.cdf(x,loc=0,scale=1);

# %%
plt.plot(x,Fx);

# %%
logfx = norm.logpdf(x,loc=0,scale=1)

# %%
plt.plot(x,logfx);

# %% [markdown]
# # Convolution

# %%
from PIL import Image

# %%
# !wget https://upload.wikimedia.org/wikipedia/en/1/19/Batman_%28circa_2016%29.png
# Out:
# --2020-08-09 10:03:26--  https://upload.wikimedia.org/wikipedia/en/1/19/Batman_%28circa_2016%29.png
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.153.240, 2620:0:860:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.153.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 115269 (113K) [image/png]
# Saving to: ‘Batman_(circa_2016).png’
#
# Batman_(circa_2016) 100%[===================>] 112.57K  --.-KB/s    in 0.07s
#
# 2020-08-09 10:03:26 (1.64 MB/s) - ‘Batman_(circa_2016).png’ saved [115269/115269]

# %%
im = Image.open('Batman_(circa_2016).png')

# %%
gray = np.mean(im,axis=2)

# %%
x = np.linspace(-6,6,50)

# %%
fx = norm.pdf(x,loc=0,scale=1);

# %%
filt = np.outer(fx,fx)

# %%
plt.imshow(filt,cmap='gray');

# %%
from scipy.signal import convolve2d

# %%
out = convolve2d(gray,filt)

# %%
plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray');
plt.subplot(1,2,2)
plt.imshow(out,cmap='gray');
